# %%
import numpy as np

def gauss1dfunct(p, xgrid):
    """
    For this function, we need to input the four parameters in p [p[0], p[1], p[2], and p[3]], 
    and the x range in data. The parameters refer to the constant term, amplitude term, 
    stdev term, and center term respectively.
    The output will be y and the jacobian.
    """
    
    U0 = (xgrid - p[3]) / p[2]
    U = U0**2
    U2 = p[1] * U0 / p[2]
    U3 = U2 * U0
    expU = np.exp(-U / 2)
    
    y = p[0] + p[1] * expU
    
    # The Jacobian of Gauss1d
    jac = np.zeros((len(xgrid), 4))
    jac[:, 0] = 1.0
    jac[:, 1] = expU
    jac[:, 2] = U3 * expU
    jac[:, 3] = U2 * expU
    
    return y, jac

# %%
import numpy as np
from scipy.optimize import curve_fit
from scipy.signal import savgol_filter

def smooth(y, span):
    return savgol_filter(y, span, 1)

def gauss1dfit(ydata, xdata):
    # Fitting 1d gaussian to data using curve_fit in Python.
    # There are two inputs. Both are required, to make it simple. The first is the raw
    # data, the second is the x-axis data.
    # An estimate will be calculated for initial parameters.
    # The output contains the fitted data and the fitted parameters
    
    yLength = len(ydata)
    if yLength < 6:
        raise ValueError("Data must have more than 6 elements")
    
    span = round(0.005 * yLength)
    if span < 5:
        span = 5
    ySmooth = smooth(ydata, span)
    base, imin = np.min(ySmooth), np.argmin(ySmooth)
    
    if imin - span > 0 and imin + span < yLength:
        base = np.mean(ySmooth[(imin - span):(imin + span)])
    
    yOffset = ydata - base
    ymax, imax = np.max(yOffset), np.argmax(yOffset)
    if imax == 0 or imax == yLength - 1:
        return [], []

    xdata1 = np.concatenate(([2 * xdata[1]], xdata[2:], [2 * xdata[-1]]))
    xdata2 = np.concatenate(([2 * xdata[0]], xdata[:-2], [2 * xdata[-2]]))
    xwidth = (xdata1 - xdata2) / 2

    yArea = yOffset * xwidth
    total = np.sum(yArea)
    StdevArea = 0.683 * total
    yStdev = yArea[imax]

    i = 1
    while (imax + i) < yLength and (imax - i) > 0 and yStdev < StdevArea:
        yStdev = yStdev + yArea[imax + i] + yArea[imax - i]
        i += 1

    Stdev = (xdata[imax + i] - xdata[imax - i]) / 2
    
    def gauss1dfunct_wrapper(x, a, b, c, d):
        return gauss1dfunct([a, b, c, d], x)[0]

    p0 = [base, ymax, Stdev, xdata[imax]]

    popt, pcov = curve_fit(gauss1dfunct_wrapper, xdata, ydata, p0)
    ret = pcov.shape[0]
    
    return popt, ret

# %%
### Testing Gauss1D fit
import matplotlib.pyplot as plt

def generate_gaussian_data(a, b, c, d, x, noise_std=0.1):
    noise = np.random.normal(0, noise_std, len(x))
    y = a + b * np.exp(-(x - d)**2 / (2 * c**2)) + noise
    return y

def test_gauss1dfit():
    # Generate synthetic data
    a, b, c, d = 1, 2, 3, 4
    x = np.linspace(0, 10, 100)
    y = generate_gaussian_data(a, b, c, d, x)

    # Fit the data
    popt, _ = gauss1dfit(y, x)

    # Check if the fitted parameters are close to the true parameters
    np.testing.assert_allclose(popt, [a, b, c, d], rtol=0.2)

    # Plot the results for visual inspection
    plt.plot(x, y, 'o', label='Noisy data')
    plt.plot(x, gauss1dfunct(popt, x)[0], '-', label='Fitted curve')
    plt.legend()
    plt.show()

test_gauss1dfit()

# %%
import numpy as np

def gauss2dfunct(p, grid, return_jac=False):
    nx = grid[0]
    ny = grid[1]

    m = len(p)
    jac = np.zeros((ny * nx, m))

    tilt = len(p) == 7
    if tilt:
        xpt = np.tile(grid[2:nx+2] - p[4], (ny, 1))
        ypt = np.tile(grid[nx+2:] - p[5], (1, nx))
        s = np.sin(p[6])
        c = np.cos(p[6])
        xp = np.reshape(xpt * (c / p[2]) - ypt * (s / p[2]), ny * nx)
        yp = np.reshape(xpt * (s / p[3]) + ypt * (c / p[3]), ny * nx)
        expU = np.exp(-0.5 * (xp * xp + yp * yp))
        z = p[0] + p[1] * expU

        if return_jac:
            pexpU = p[1] * expU
            Ux = pexpU * xp / p[2]
            Uy = pexpU * yp / p[3]
            jac[:, 0] = 1
            jac[:, 1] = expU
            jac[:, 2] = Ux / p[2]
            jac[:, 3] = Uy / p[3]
            jac[:, 4] = Ux * c + Uy * s
            jac[:, 5] = -Ux * s + Uy * c
            jac[:, 6] = -pexpU * xp * yp * (p[2] / p[3] - p[3] / p[2])
            return z, jac
    else:
        xp = np.reshape(np.tile((grid[2:nx+2] - p[4]) / p[2], (ny, 1)), ny * nx)
        yp = np.reshape(np.tile((grid[nx+2:] - p[5]) / p[3], (1, nx)), ny * nx)
        expU = np.exp(-0.5 * (xp * xp + yp * yp))
        z = p[0] + p[1] * expU

        if return_jac:
            pexpU = p[1] * expU
            Ux = pexpU * xp / p[2]
            Uy = pexpU * yp / p[3]
            jac[:, 0] = 1
            jac[:, 1] = expU
            jac[:, 2] = Ux / p[2]
            jac[:, 3] = Uy / p[3]
            jac[:, 4] = Ux
            jac[:, 5] = Uy
            return z, jac

    return z

# %%
import numpy as np
from scipy.optimize import least_squares

def gauss2dfit(zdata, grid, tilt):
    nx, ny = grid[0], grid[1]
    z = zdata.flatten()

    # Compute moments for initial estimates
    x = np.arange(1, nx + 1)
    y = np.arange(1, ny + 1)
    X, Y = np.meshgrid(x, y)

    z_offset = np.min(zdata)
    amplitude = np.max(zdata) - z_offset

    x_center = np.sum(X * zdata) / np.sum(zdata)
    y_center = np.sum(Y * zdata) / np.sum(zdata)

    x_std = np.sqrt(np.abs(np.sum(((X - x_center) ** 2) * zdata) / np.sum(zdata)))
    y_std = np.sqrt(np.abs(np.sum(((Y - y_center) ** 2) * zdata) / np.sum(zdata)))

    p0 = [z_offset, amplitude, x_std, y_std, x_center, y_center]

    if tilt == 1:
        p0.append(0)

    def residuals(p, grid, z):
        z_model = gauss2dfunct(p, grid)
        return z - z_model

    result = least_squares(residuals, p0, args=(grid, z), method='lm', ftol=1e-10, xtol=1e-10, max_nfev=1000)

    popt = result.x
    resnorm = result.cost
    residual = result.fun
    ret = result.nfev

    return popt, resnorm, residual, ret

# %%
## Testing gauss2dfit
import numpy as np

def generate_2d_gaussian_data(nx, ny, z_offset, amplitude, x_std, y_std, x_center, y_center, tilt=0, noise_level=0.1):
    x = np.linspace(1, nx, nx)
    y = np.linspace(1, ny, ny)
    xv, yv = np.meshgrid(x, y)

    s = np.sin(tilt)
    c = np.cos(tilt)

    xp = (xv - x_center) * c / x_std + (yv - y_center) * s / x_std
    yp = -(xv - x_center) * s / y_std + (yv - y_center) * c / y_std

    z = z_offset + amplitude * np.exp(-0.5 * (xp ** 2 + yp ** 2))

    noise = np.random.normal(0, noise_level * amplitude, (ny, nx))
    z_noisy = z + noise

    return z_noisy

def test_gauss2dfit():
    np.random.seed(42)
    
    nx, ny = 100, 100
    z_offset, amplitude = 4.0, 100.0
    x_std, y_std = 10.0, 15.0
    x_center, y_center = 45, 55
    tilt = 0

    # Test with different noise levels
    noise_levels = np.linspace(0, 5, 200)
    tolerance = 0.5

    for noise_level in noise_levels:
        synthetic_data = generate_2d_gaussian_data(nx, ny, z_offset, amplitude, x_std, y_std, x_center, y_center, tilt, noise_level)
        grid = np.hstack(([nx, ny], np.arange(1, nx + 1), np.arange(1, ny + 1)))
        popt, _, _, _ = gauss2dfit(synthetic_data, grid, tilt)

        true_params = np.array([z_offset, amplitude, x_std, y_std, x_center, y_center])
        relative_errors = np.abs((popt - true_params) / true_params)

        assert np.all(relative_errors < tolerance), f"Noise level: {noise_level}, Relative errors exceed tolerance: {relative_errors}"

test_gauss2dfit()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_380\3537909284.py in <module>
#      43         assert np.all(relative_errors < tolerance), f"Noise level: {noise_level}, Relative errors exceed tolerance: {relative_errors}"
#      44
# ---> 45 test_gauss2dfit()
#
# ~\AppData\Local\Temp\ipykernel_380\3537909284.py in test_gauss2dfit()
#      41         relative_errors = np.abs((popt - true_params) / true_params)
#      42
# ---> 43         assert np.all(relative_errors < tolerance), f"Noise level: {noise_level}, Relative errors exceed tolerance: {relative_errors}"
#      44
#      45 test_gauss2dfit()
#
# AssertionError: Noise level: 0.02512562814070352, Relative errors exceed tolerance: [0.00977711 0.04677524 3.05906335 0.3139656  1.19215585 0.11905366]

# %%
def PSFfit(IMAGE, pxl_size):
    ny, nx = IMAGE.shape
    grid = [nx, ny] + list(range(1, nx+1)) + list(range(1, ny+1))
    popt, _, _, _ = gauss2dfit(np.abs(IMAGE), grid, 0)

    if popt.size != 0:
        xp = np.reshape(np.repeat((grid[2:nx+2] - popt[4]) / popt[2], ny), (ny * nx, 1)).flatten()
        yp = np.reshape(np.repeat((grid[nx+2:] - popt[5]) / popt[3], nx), (ny * nx, 1)).flatten()

        expU = np.exp(-0.5 * (xp * xp + yp * yp))
        z = popt[0] + popt[1] * expU

        N = np.sum(z - popt[0])
        z = np.reshape(z, (ny, nx))
        si_x = popt[2] * pxl_size
        si_y = popt[3] * pxl_size
        a = pxl_size

        bkg = np.reshape(IMAGE - z, -1).flatten()
        b = np.std(bkg)

        sig_ax2 = si_x ** 2 + a ** 2 / 12
        sig_ay2 = si_y ** 2 + a ** 2 / 12

        eps = 1e-10
        sig_x = np.sqrt(sig_ax2 / (N + eps) * (16 / 9 + 8 * np.pi * sig_ax2 * b ** 2 / ((N + eps) * a ** 2)))
        sig_y = np.sqrt(sig_ay2 / (N + eps) * (16 / 9 + 8 * np.pi * sig_ay2 * b ** 2 / ((N + eps) * a ** 2)))
    else:
        sig_x, sig_y, N = [], [], []

    return sig_x, sig_y, N

# %%
import numpy as np
from scipy.ndimage import median_filter, convolve
from skimage.measure import regionprops
from skimage.morphology import label
import matplotlib.pyplot as plt

def fast_peak_find(d, thres=None, filt=None, edg=3, res=1, filename=None):
    if thres is None:
        thres = max(np.min(d, axis=0).max(), np.min(d, axis=1).max())
    
    if filt is None:
        filt = np.ones((7, 7)) / 49
    
    d = median_filter(d, size=(3, 3))
    d[d <= thres] = 0
    
    if np.any(d):
        d = convolve(d, filt, mode='constant')
        d[d <= 0.9 * thres] = 0
        
        if res == 1:
            sd = d.shape
            x, y = np.where(d[edg:sd[0] - edg, edg:sd[1] - edg])
            
            cent = []
            cent_map = np.zeros(sd)
            
            x = x + edg - 1
            y = y + edg - 1
            
            for j in range(len(y)):
                if (d[x[j], y[j]] > d[x[j] - 1, y[j] - 1]) and \
                   (d[x[j], y[j]] > d[x[j] - 1, y[j]]) and \
                   (d[x[j], y[j]] > d[x[j] - 1, y[j] + 1]) and \
                   (d[x[j], y[j]] > d[x[j], y[j] - 1]) and \
                   (d[x[j], y[j]] > d[x[j], y[j] + 1]) and \
                   (d[x[j], y[j]] > d[x[j] + 1, y[j] - 1]) and \
                   (d[x[j], y[j]] > d[x[j] + 1, y[j]]) and \
                   (d[x[j], y[j]] > d[x[j] + 1, y[j] + 1]):
                    
                    cent.append(y[j])
                    cent.append(x[j])
                    cent_map[x[j], y[j]] = cent_map[x[j], y[j]] + 1
        else:
            labeled_img = label(d > 0)
            stats = regionprops(labeled_img, d, properties=['area', 'weighted_centroid'])
            
            rel_peaks = [s for s in stats if s['area'] <= np.mean([s['area'] for s in stats]) + 2 * np.std([s['area'] for s in stats])]
            cent = [coord for s in rel_peaks for coord in s['weighted_centroid']]
            cent_map = None
    
        if filename:
            with open(filename, 'a') as f:
                f.write(' '.join([str(c) for c in cent]) + '\n')
    else:
        cent = []
        cent_map = np.zeros(d.shape)
    
    return np.array(cent), d, cent_map

# %%
import numpy as np
from tifffile import TiffFile

def load_tiff_movie(pathname, filename):
    filepath = pathname + filename

    with TiffFile(filepath) as tif:
        num_frame = len(tif.pages)
        raw_frames = [np.array(page.asarray()) for page in tif.pages]

    return raw_frames, num_frame

# %%
from scipy.ndimage import gaussian_filter

def gaussian_image_filtering(image, sigma):
    filtered_image = gaussian_filter(image, sigma=sigma)
    return filtered_image, None

# %%
import numpy as np
from scipy.ndimage import label
from matplotlib import pyplot as plt

def fit_molecules(pathname, filename):
    raw_frames, num_frame = load_tiff_movie(pathname, filename)
    curr_frame = raw_frames[0]

    print("Raw frames loaded, total number of frames:", num_frame)

    pxl_size = 43.3
    nbors = 15
#     thres = 1250
    thres = 250
    D0 = 25
    D1 = 1
    R = 20

    Z_uncertainty = []
    XYpos = []
    xy_uncertainty = []
    cent_final = np.zeros((2, 1))
    MOLE_final = [None]
    INTERF_final = [None]

    for ii in range(num_frame):
        curr_frame = raw_frames[ii]
        B1, B2 = gaussian_image_filtering(curr_frame, D0)
        
        gg = B1
        L, W = gg.shape
        print("Filtered image shape:", gg.shape)
        
        cent, _, _ = fast_peak_find(gg, thres)
        print("Found", cent.shape[0], "centroids")
#         if cent:
#             print("Found", len(cent[0]), "centroids")
#         else:
#             print("Found 0 centroids")


        if cent.size > 0:
            cent = np.array(cent).reshape(2, -1)
        else:
            cent = np.empty((2, 0))
        cent = cent[:, np.logical_and(np.logical_and(cent[0] > nbors, cent[0] < W - nbors), np.logical_and(cent[1] > nbors, cent[1] < L - nbors))]

        xx, yy = np.meshgrid(np.arange(1, L + 1), np.arange(1, W + 1))

        for jj in range(cent.shape[1]):
            R2C = (xx - cent[0, jj])**2 / R**2 + (yy - cent[1, jj])**2 / R**2
            circlefilt = (R2C < 1)

            ISOLATE = gg * circlefilt
            cISO = curr_frame * circlefilt
            INTERF = cISO[cent[1, jj] - nbors:cent[1, jj] + nbors, cent[0, jj] - nbors:cent[0, jj] + nbors]

            MOLE, _ = gaussian_image_filtering(INTERF, D1)
            print("INTERF shape:", INTERF.shape)
            print("MOLE shape:", MOLE.shape)

            sig_x, sig_y, N = PSFfit(np.abs(MOLE), pxl_size)
            xy_uncertainty.append([sig_x, sig_y, N])

            if N:
                print("Molecule fit successful for centroid", jj)
                cent_final = np.hstack([cent_final, cent[:, [jj]]])
                MOLE_final.append(MOLE)
                INTERF_final.append(INTERF)

    cent_final = cent_final[:, 1:]
    MOLE_final = [x for x in MOLE_final if x is not None]
    INTERF_final = [x for x in INTERF_final if x is not None]

    if cent_final.size > 0:
        distFromCenter = np.sqrt((cent_final[0] - 512)**2 + (cent_final[1] - 512)**2)
        mindist = np.argmin(distFromCenter)
    else:
        mindist = None

    xy_uncertainty = np.array(xy_uncertainty)
    print("cent_final shape:", cent_final.shape)
    print("MOLE_final length:", len(MOLE_final))
    print("INTERF_final length:", len(INTERF_final))
    print("xy_uncertainty shape:", xy_uncertainty.shape)
    print("mindist:", mindist)
    return cent_final, MOLE_final, INTERF_final, xy_uncertainty, mindist

# %%
pathname = 'C:/Users/icedn/Jupyter/SelvinLab/MatLab to Python/'
filename = 'TSB_488.tif'
cent_final, MOLE_final, INTERF_final, xy_uncertainty, mindist = fit_molecules(pathname, filename)
# Out:
# TiffTag 5033: coercing invalid ASCII to bytes
# Raw frames loaded, total number of frames: 10
# Filtered image shape: (1024, 1024)
# Found 2 centroids
# INTERF shape: (30, 30)
# MOLE shape: (30, 30)
# Molecule fit successful for centroid 0
# Filtered image shape: (1024, 1024)
# Found 0 centroids
# Filtered image shape: (1024, 1024)
# Found 0 centroids
# Filtered image shape: (1024, 1024)
# Found 2 centroids
# INTERF shape: (30, 30)
# MOLE shape: (30, 30)
# Molecule fit successful for centroid 0
# Filtered image shape: (1024, 1024)
# Found 0 centroids
# Filtered image shape: (1024, 1024)
# Found 0 centroids
# Filtered image shape: (1024, 1024)
# Found 2 centroids
# INTERF shape: (30, 30)
# MOLE shape: (30, 30)
# Molecule fit successful for centroid 0
# Filtered image shape: (1024, 1024)
# Found 4 centroids
# INTERF shape: (30, 30)
# MOLE shape: (30, 30)
# Molecule fit successful for centroid 0
# INTERF shape: (30, 30)
# MOLE shape: (30, 30)
# Molecule fit successful for centroid 1
# Filtered image shape: (1024, 1024)
# Found 0 centroids
# Filtered image shape: (1024, 1024)
# Found 0 centroids
# cent_final shape: (2, 5)
# MOLE_final length: 5
# INTERF_final length: 5
# xy_uncertainty shape: (5, 3)
# mindist: 1

# %%
import matplotlib.patches as patches

def display_boxes(raw_frames, cent_final, box_size=30):
    num_frames = len(raw_frames)
    num_frames = 2
    fig, axs = plt.subplots(1, num_frames, figsize=(15, 15))

    for i, frame in enumerate(raw_frames):
        axs[i].imshow(frame, cmap='gray')
        axs[i].set_title(f'Frame {i+1}')
        axs[i].axis('off')

        for j in range(cent_final.shape[1]):
            x, y = cent_final[:, j]
            rect = patches.Rectangle((x - box_size / 2, y - box_size / 2),
                                      box_size, box_size,
                                      linewidth=1, edgecolor='r', facecolor='none')
            axs[i].add_patch(rect)

    plt.tight_layout()
    plt.show()

# Use the function to display the boxes
raw_frames, num_frame = load_tiff_movie(pathname, filename)
display_boxes(raw_frames, cent_final)
# Out:
# TiffTag 5033: coercing invalid ASCII to bytes
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_380\523925165.py in <module>
#      23 # Use the function to display the boxes
#      24 raw_frames, num_frame = load_tiff_movie(pathname, filename)
# ---> 25 display_boxes(raw_frames, cent_final)
#
# ~\AppData\Local\Temp\ipykernel_380\523925165.py in display_boxes(raw_frames, cent_final, box_size)
#       7
#       8     for i, frame in enumerate(raw_frames):
# ----> 9         axs[i].imshow(frame, cmap='gray')
#      10         axs[i].set_title(f'Frame {i+1}')
#      11         axs[i].axis('off')
#
# IndexError: index 2 is out of bounds for axis 0 with size 2
